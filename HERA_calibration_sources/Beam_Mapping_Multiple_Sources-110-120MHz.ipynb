# %%
from astropy.io import fits
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
from astropy.wcs import WCS
from HERA_calibration_sources import add_fluxes

plt.rc('font', family='serif')
plt.rc('xtick', labelsize='small')
plt.rc('ytick', labelsize='small')

# %%
files = np.sort(glob('/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/*fits'))
HDUS = []

for f in files:
    HDUS.append(fits.open(f))
    
print files
# Out:
# ['/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.12552.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.13298.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.14043.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.14789.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.15535.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.16280.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.17026.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.17772.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.18517.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.19263.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.20009.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.20754.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.21500.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.22245.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.22991.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.23737.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.24482.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.25228.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.25974.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.26719.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.27465.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.28211.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.28956.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.29702.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.30448.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.31193.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.31939.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.32685.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.33430.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.34176.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.34922.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.35667.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.36413.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.37159.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.37904.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.38650.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.39396.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.40141.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.40887.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.41632.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.42378.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.43124.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.43869.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.44615.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.45361.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.46106.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.46852.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.47598.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.48343.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.49089.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.49835.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.50580.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.51326.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.52072.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.52817.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.53563.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.54309.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.55054.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.55800.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.56546.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.57291.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.58037.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.58783.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.59528.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.60274.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.61020.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.61765.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.62511.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.63256.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.64002.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.64748.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.65493.xx.HH.uvR.uvfits.msFinal.combined.img.fits'
#  '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.66239.xx.HH.uvR.uvfits.msFinal.combined.img.fits']

# %%
tb = add_fluxes(RA_range=('00:00:00','24:00:00'),dec_range=1, min_flux=5)
tb
# Out:
# Right ascension:
# 	Lower: 00h00m00s
# 	Upper: 24h00m00s
# Declination:
# 	Lower: -31.7214 degrees
# 	Upper: -29.7214 degrees
# Minimum flux: 5 Jy
# Number of regions found: 30
#
#               Name of Center          RA        Dec  Total flux in region
# 0   TGSSADR J020012.1-305327   30.050440 -30.891060          25311.699249
# 1   TGSSADR J022720.2-303750   36.834339 -30.630619           9238.400185
# 2   TGSSADR J043300.3-295615   68.251488 -29.937559          10452.800014
# 3   TGSSADR J043736.5-295406   69.402321 -29.901720           9057.500076
# 4   TGSSADR J045826.4-300720   74.610413 -30.122379          19984.100246
# 5   TGSSADR J045514.2-300650   73.809464 -30.113991          23645.400387
# 6   TGSSADR J051330.6-303042   78.377602 -30.511909          18364.499821
# 7   TGSSADR J051342.7-302455   78.428291 -30.415541          17800.299809
# 8   TGSSADR J073819.7-302505  114.582474 -30.418230          14347.499702
# 9   TGSSADR J082126.4-301105  125.360031 -30.184980          20358.700781
# 10  TGSSADR J100140.4-305824  150.418594 -30.973551           9961.400051
# 11  TGSSADR J125722.8-302147  194.345398 -30.363331           9929.599907
# 12  TGSSADR J140420.9-295204  211.087433 -29.867910           8231.400208
# 13  TGSSADR J142529.1-295956  216.371628 -29.999001          22982.300377
# 14  TGSSADR J142155.5-310428  215.481415 -31.074530          12421.300392
# 15  TGSSADR J141439.1-302541  213.663132 -30.428080          13903.600189
# 16  TGSSADR J151155.5-304504  227.981674 -30.751249           9922.599945
# 17  TGSSADR J162555.4-310809  246.481018 -31.135880          15390.600384
# 18  TGSSADR J170745.4-303039  256.939178 -30.510910          12612.200081
# 19  TGSSADR J170109.7-295441  255.290695 -29.911631          13686.599632
# 20  TGSSADR J165956.9-305205  254.987228 -30.868139          18871.499599
# 21  TGSSADR J171007.9-294849  257.532959 -29.813700          12253.499840
# 22  TGSSADR J174024.3-305744  265.101349 -30.962481          67464.900024
# 23  TGSSADR J174012.7-305831  265.053101 -30.975340          67636.000031
# 24  TGSSADR J173743.8-313117  264.432587 -31.521400           9006.299850
# 25  TGSSADR J185710.6-301943  284.294281 -30.328739          14750.599586
# 26  TGSSADR J191927.5-295802  289.864777 -29.967440          11346.200375
# 27  TGSSADR J213123.1-312113  322.846497 -31.353800          11193.800449
# 28  TGSSADR J211810.6-301915  319.544403 -30.320959          14464.699615
# 29  TGSSADR J224633.8-304447  341.641205 -30.746460           7199.100218
#               Name of Center          RA        Dec  Total flux in region
# 0   TGSSADR J020012.1-305327   30.050440 -30.891060          25311.699249
# 1   TGSSADR J022720.2-303750   36.834339 -30.630619           9238.400185
# 2   TGSSADR J043300.3-295615   68.251488 -29.937559          10452.800014
# 3   TGSSADR J043736.5-295406   69.402321 -29.901720           9057.500076
# 4   TGSSADR J045826.4-300720   74.610413 -30.122379          19984.100246
# 5   TGSSADR J045514.2-300650   73.809464 -30.113991          23645.400387
# 6   TGSSADR J051330.6-303042   78.377602 -30.511909          18364.499821
# 7   TGSSADR J051342.7-302455   78.428291 -30.415541          17800.299809
# 8   TGSSADR J073819.7-302505  114.582474 -30.418230          14347.499702
# 9   TGSSADR J082126.4-301105  125.360031 -30.184980          20358.700781
# 10  TGSSADR J100140.4-305824  150.418594 -30.973551           9961.400051
# 11  TGSSADR J125722.8-302147  194.345398 -30.363331           9929.599907
# 12  TGSSADR J140420.9-295204  211.087433 -29.867910           8231.400208
# 13  TGSSADR J142529.1-295956  216.371628 -29.999001          22982.300377
# 14  TGSSADR J142155.5-310428  215.481415 -31.074530          12421.300392
# 15  TGSSADR J141439.1-302541  213.663132 -30.428080          13903.600189
# 16  TGSSADR J151155.5-304504  227.981674 -30.751249           9922.599945
# 17  TGSSADR J162555.4-310809  246.481018 -31.135880          15390.600384
# 18  TGSSADR J170745.4-303039  256.939178 -30.510910          12612.200081
# 19  TGSSADR J170109.7-295441  255.290695 -29.911631          13686.599632
# 20  TGSSADR J165956.9-305205  254.987228 -30.868139          18871.499599
# 21  TGSSADR J171007.9-294849  257.532959 -29.813700          12253.499840
# 22  TGSSADR J174024.3-305744  265.101349 -30.962481          67464.900024
# 23  TGSSADR J174012.7-305831  265.053101 -30.975340          67636.000031
# 24  TGSSADR J173743.8-313117  264.432587 -31.521400           9006.299850
# 25  TGSSADR J185710.6-301943  284.294281 -30.328739          14750.599586
# 26  TGSSADR J191927.5-295802  289.864777 -29.967440          11346.200375
# 27  TGSSADR J213123.1-312113  322.846497 -31.353800          11193.800449
# 28  TGSSADR J211810.6-301915  319.544403 -30.320959          14464.699615
# 29  TGSSADR J224633.8-304447  341.641205 -30.746460           7199.100218

# %%
plot_data = {v['Name of Center']: {'RA_diff': [], 'Flux': [], 'time': [],'Pixel_x': [],'Pixel_y': []} for _,v in tb.iterrows()}
source_info = {v['Name of Center']: {'RA': v['RA'], 'DEC': v['Dec'], 
                                     'Total_Flux': v['Total flux in region']} 
                                     for _,v in tb.iterrows()}

# %%
err = 3

f_count = len(files)
t = 0.0

c_prev = 0

for HDU,f in zip(HDUS,files):
    print ('Processing: ', f)
    # Read in file information
    fits_info = HDU[0].header
    ax1        = fits_info['NAXIS1']
    ax2        = fits_info['NAXIS2']
    units      = fits_info['BUNIT']
    c_ra       = fits_info['OBSRA']
    c_dec      = fits_info['OBSDEC']
    pix_size   = fits_info['CDELT2']
    c_pix1     = fits_info['CRPIX1']
    c_pix2     = fits_info['CRPIX2']
    
    data = HDU[0].data
    data = np.flip(data[0][0],axis=0)
    
    w = WCS(f)
    l_bound = w.all_pix2world(c_pix1,0,0,0,0)[0]
    r_bound = w.all_pix2world(c_pix1,ax2,0,0,0)[0]
    
    t += 1.0

    for _,src in tb.iterrows():
        # Convert a position to pixel values
        i,j = w.all_world2pix(src['RA'],src['Dec'],0,0,0)[:2]
        try:
            i = int(i)
            j = int(ax2-j)
        except:
            pass
        
        if (ax1-err > i > err) and (ax2-err > j > err):
            plot_data[src['Name of Center']]['Flux'].append(np.abs(data[j-err:j+err,i-err:i+err].max())/src['Total flux in region'])
            #plot_data[src['Name of Center']]['Flux'].append(np.abs(data[j-err:j+err,i-err:i+err].max()))
            ra_diff = c_ra-src['RA']
            
            # Correct for the difference in c_ra error
            if ra_diff > 30:
                ra_diff -= 360
            if ra_diff < -30:
                ra_diff += 360
                
            t = c_ra
                
            if c_ra-c_prev < -30:
                t = c_ra+360
            plot_data[src['Name of Center']]['RA_diff'].append(ra_diff)
            plot_data[src['Name of Center']]['time'].append(t)
            plot_data[src['Name of Center']]['Pixel_x'].append(j)
            plot_data[src['Name of Center']]['Pixel_y'].append(i)
    c_prev = c_ra
# Out:
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.12552.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# WARNING: FITSFixedWarning: PC01_01 = 1.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC02_01 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC03_01 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC04_01 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC01_02 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC02_02 = 1.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC03_02 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC04_02 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC01_03 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC02_03 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC03_03 = 1.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC04_03 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC01_04 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC02_04 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC03_04 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC04_04 = 1.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.13298.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.14043.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.14789.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.15535.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.16280.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.17026.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.17772.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.18517.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.19263.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.20009.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.20754.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.21500.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.22245.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.22991.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.23737.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.24482.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.25228.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.25974.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.26719.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.27465.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.28211.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.28956.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.29702.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.30448.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.31193.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.31939.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.32685.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.33430.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.34176.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.34922.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.35667.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.36413.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.37159.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.37904.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.38650.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.39396.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.40141.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.40887.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.41632.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.42378.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.43124.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.43869.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.44615.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.45361.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.46106.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.46852.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.47598.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.48343.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.49089.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.49835.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.50580.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.51326.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.52072.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.52817.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.53563.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.54309.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.55054.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.55800.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.56546.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.57291.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.58037.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.58783.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.59528.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.60274.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.61020.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.61765.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.62511.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.63256.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.64002.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.64748.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.65493.xx.HH.uvR.uvfits.msFinal.combined.img.fits')
# ('Processing: ', '/data6/HERA/HERA_imaging/2458042/110-120MHz/imgs/zen.2458042.66239.xx.HH.uvR.uvfits.msFinal.combined.img.fits')

# %%
for k,v in plot_data.iteritems():
    print (len(v['Flux']))
# Out:
# 3
# 0
# 1
# 16
# 5
# 0
# 0
# 0
# 0
# 15
# 6
# 3
# 15
# 15
# 13
# 2
# 15
# 15
# 16
# 0
# 6
# 0
# 16
# 6
# 16
# 15
# 0
# 2
# 15
# 15

# %%
cleaned_set = {k: v for k,v in plot_data.iteritems() if len(v['Flux']) >= 15}
len(cleaned_set)
# Out:
# 12

# %%
plt.figure(figsize=(20,10))

for key,item in cleaned_set.items():
    theta = item['RA_diff']
    flux = np.array(item['Flux'])
    plt.xlabel(r'Beam Angle $\theta$')
    plt.ylabel(r'Normalized Flux Density')
    #plt.title(key)
    plt.plot(theta,10*np.log10(flux),label=key)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

for key,item in cleaned_set.items():
    theta = item['time']
    flux = np.array(item['Flux'])
    plt.xlabel(r'Zenith Right Ascension')
    plt.ylabel('Normalized Flux Density')
    plt.plot(theta,10*np.log10(flux),label=key)
    
plt.title('Position of Sources Relative to Zenith over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

for key,item in cleaned_set.items():
    theta = item['RA_diff']
    flux = np.array(item['Flux'])
    plt.xlabel(r'Beam Angle $\theta$')
    plt.ylabel('Normalized Flux Density')
    plt.plot(theta,10*np.log10(flux),label=key)
    
plt.title('Normalized Flux Density vs. Beam Angle')
plt.legend()
plt.show()

# %%
for key,item in cleaned_set.items():
    print len(item['Flux'])
# Out:
# 15
# 15
# 16
# 16
# 15
# 15
# 15
# 16
# 16
# 15
# 15
# 15

# %%
n = 15
l = np.zeros(n)
plt.figure(figsize=(10,5))

c = 0

for key,item in cleaned_set.items():
    theta = item['RA_diff']
    flux = np.array(item['Flux'])
    if len(flux) == n:
        l += flux
        c += 1

f = np.vstack([10*np.log10(item['Flux']) for key,item in cleaned_set.items() if len(item['Flux'])==n])

std = [np.std(f[:,i]) for i in range(f.shape[1])]

plt.figure(figsize=(10,5))

plt.plot(np.linspace(-22,22,len(std)),std,'k')
plt.title(r'Standard Deviation vs. Beam Angle')
plt.xlabel(r'$\theta$')
plt.ylabel(r'$\sigma^2$')
       

plt.figure(figsize=(10,5))

plt.xlabel(r'$\theta$')
plt.ylabel('Normalized Flux Density')
plt.title('Mean Beam Sensitivity')
plt.plot(range(l.size),10*np.log10(l/c))
plt.show()

# %%
import healpy as hp

# %%
filename = 'healpix_beam.fits'
beam_E = fits.getdata(filename, extname='BEAM_E')
nside = hp.npix2nside(beam_E.shape[0])
freqs = fits.getdata(filename, extname='FREQS')
freqs = freqs[60:71]
freqs
# Out:
# array([110., 111., 112., 113., 114., 115., 116., 117., 118., 119., 120.])

# %%
# Loop over all frequencies
n = 30
m_theta = np.deg2rad(np.linspace(0,22,n))

normed_vals = np.array([])

for freq in freqs:
    ind = np.where(freqs == freq)[0][0]
    data = beam_E[:,ind]
    phi0 = np.deg2rad(0)
    vals0 = hp.ang2pix(nside,m_theta,phi0)
    plt0 = 10*np.log10(data[vals0])
    if normed_vals.shape[0] == 0:
        normed_vals = plt0
    else:
        normed_vals = np.vstack([normed_vals,plt0])

m_theta = np.concatenate([-np.flip(m_theta,axis=0),m_theta])
normed_vals = np.hstack([np.flip(normed_vals,axis=1),normed_vals])

# %%
model_std = np.array([np.std(normed_vals[:,i]) for i in range(normed_vals.shape[1])])
model = np.array([np.mean(normed_vals[:,i]) for i in range(normed_vals.shape[1])])

plt.rc('font', family='serif')
plt.figure(figsize=(10,5))
plt.title('Directivity Over All Frequencies')
plt.xlabel('Beam Angle')
plt.ylabel('Amplitude')
plt.errorbar(np.rad2deg(m_theta),model,yerr=model_std,color='k',label=(r'$\alpha$ = ' + str(phi0)))
plt.show()

# %%
print normed_vals[0,:]
# Out:
# [-9.12885843 -7.4585026  -6.01306655 -4.74993172 -3.63418514 -2.63940958
#  -1.74518201 -0.93699124 -0.20323732  0.46616528  1.0782474   1.63928361
#   2.15408623  2.62636707  3.05980792  3.45754808  3.82023235  4.1519147
#   4.45462799  4.7282456   4.97399473  5.19452636  5.38877594  5.55811611
#   5.70462572  5.82660458  5.92639497  6.00365181  6.05745377  6.09005517
#   6.09005517  6.05745377  6.00365181  5.92639497  5.82660458  5.70462572
#   5.55811611  5.38877594  5.19452636  4.97399473  4.7282456   4.45462799
#   4.1519147   3.82023235  3.45754808  3.05980792  2.62636707  2.15408623
#   1.63928361  1.0782474   0.46616528 -0.20323732 -0.93699124 -1.74518201
#  -2.63940958 -3.63418514 -4.74993172 -6.01306655 -7.4585026  -9.12885843]

# %%
plt.rc('font', family='serif')
plt.figure(figsize=(10,5))
plt.title('Model vs. Observed Data')
plt.xlabel('Beam Angle')
plt.ylabel('Amplitude')

plt.plot(np.rad2deg(m_theta),model,'k--',label=(r'Model: $\delta$ = ' + str(phi0)) + r'$^\circ$')
plt.errorbar(theta,10*np.log10(l/c)+75,yerr=std,label='Data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,7))
tot = np.array([])

for key,item in plot_data.items():
    theta = item['RA_diff']
    flux = np.array(item['Flux'])
    pix_x = np.array(item['Pixel_x'])
    pix_y = np.array(item['Pixel_y'])
    pix_x = source_info[key]['DEC']*np.ones(flux.shape[0])
    if pix_x.shape[0] != 0:
        scaled_flux = 10*np.log10(flux/flux.max())
        plt.scatter(theta,pix_x,c=scaled_flux,s=5)
        norm_flux = flux/flux.max()
        tot = np.hstack([tot,norm_flux])

plt.ylabel(r'Declination')
plt.xlabel(r'Beam Angle $\theta$')
plt.colorbar()
plt.xlim(-22,22)
plt.ylim(-22-30.7,-30.7+22)
plt.show()

# %% [markdown]
# The plot above is scaled incorrectly. When the colorbar was added it is scaled to the final source that is plotted. The next cell fixes this problem

# %%
import ECHO
import numpy as np

# %%
ang_ra = np.array([])
fluxes = np.array([])
ang_dec = np.array([])


for key,item in plot_data.items():
    theta = np.array(item['RA_diff'])
    flux = np.array(item['Flux'])
    pix_x = np.array(item['Pixel_x'])
    pix_y = np.array(item['Pixel_y'])
    pix_x = source_info[key]['DEC']*np.ones(flux.shape[0])
    if pix_x.shape[0] != 0:
        ang_ra = np.concatenate([ang_ra,theta])
        fluxes = np.concatenate([fluxes,flux/flux.max()])
        ang_dec = np.concatenate([ang_dec,pix_x])

plt.figure(figsize=(7,7))
plt.scatter(ang_ra,ang_dec,c=10*np.log10(fluxes),s=5)
plt.ylabel(r'Declination')
plt.xlabel(r'Beam Angle $\theta$')
plt.xlim(-22,22)
plt.ylim(-22-30.7,-30.7+22)
plt.colorbar()
plt.show()

# %%
grid, bins, rmsBins, _, xi, yi, gcounts, grms = ECHO.plot_utils.grid_data(ang_ra,ang_dec,10*np.log10(fluxes),binsize=0.5)

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.flip(rmsBins,axis=0))
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.flip(grid.data,axis=0))
plt.colorbar()
plt.show()

# %%
beam, rms, counts = ECHO.plot_utils.grid_to_healpix(xi,yi,alts=np.zeros_like(xi),rx=grid.data,lat0=-30,lon0=0,nside=32)

# %%
# %matplotlib inline
hp.mollzoom(beam)

# %%
print np.std([0, 1], ddof=1)
print np.std([0, 1])
# Out:
# 0.7071067811865476
# 0.5
