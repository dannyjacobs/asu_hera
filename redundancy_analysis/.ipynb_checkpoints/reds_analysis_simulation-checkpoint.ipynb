# %% [markdown]
# # HERA Redundancy Analysis Simulated Data

# %% [markdown]
# ## Shane Bechtel

# %%
#Base number for all Reds
#Add controllable noise to all bls,time,freqs
#Controllable Random Non redundant signal

import numpy as np
import matplotlib.pyplot as plt
from pyuvdata import UVData
from pyuvdata import uvutils
from hera_qm import ant_metrics
import hera_cal
from copy import deepcopy

from matplotlib.colors import SymLogNorm
import sys
import os
from hera_qm import xrfi as xrfi
import numpy.ma as ma
import glob

# %% [markdown]
# First, we store 4 miriad files, each being a different polarization of the same observation, into a list. This list is then read into a newly created UVData object

# %%
data_file_list = ['/data6/HERA/data/2458042/zen.2458042.12552.xx.HH.uv','/data6/HERA/data/2458042/zen.2458042.12552.yy.HH.uv','/data6/HERA/data/2458042/zen.2458042.12552.yx.HH.uv','/data6/HERA/data/2458042/zen.2458042.12552.xy.HH.uv']

uv = UVData()

uv.read_miriad(data_file_list)
# Out:
# Combined polarizations are not evenly spaced. This will make it impossible to write this data out to some file types.

# %% [markdown]
# Using the package hera_cal, we extract the redundant baselines which are stored in such a way that there are seperate arrays for the different sets of redundant baselines (i.e. if baseline x is redundant with baseline y, then they are in the same array, but even if baseline z has redundant baselines, if it is not redundant to baselines x and y then it is not in that array).

# %%
aa = hera_cal.utils.get_aa_from_uv(uv)

info = hera_cal.omni.aa_to_info(aa)

reds = info.get_reds()

# %%
am = ant_metrics.Antenna_Metrics(data_file_list, reds, fileformat = 'miriad')

# %%
bases = []

lst = uv.get_antpairpols()

for i in range(uv.Nbls):
    
    pair = lst[4*i]
    
    bases.append((pair[0],pair[1]))
    
print bases
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 11), (0, 12), (0, 13), (0, 14), (0, 23), (0, 24), (0, 25), (0, 26), (0, 27), (0, 36), (0, 37), (0, 38), (0, 39), (0, 40), (0, 41), (0, 50), (0, 51), (0, 52), (0, 53), (0, 54), (0, 55), (0, 65), (0, 66), (0, 67), (0, 68), (0, 69), (0, 70), (0, 71), (0, 82), (0, 83), (0, 84), (0, 85), (0, 86), (0, 87), (0, 88), (0, 98), (0, 120), (0, 121), (0, 122), (0, 123), (0, 124), (0, 141), (0, 142), (0, 143), (1, 1), (1, 2), (1, 11), (1, 12), (1, 13), (1, 14), (1, 23), (1, 24), (1, 25), (1, 26), (1, 27), (1, 36), (1, 37), (1, 38), (1, 39), (1, 40), (1, 41), (1, 50), (1, 51), (1, 52), (1, 53), (1, 54), (1, 55), (1, 65), (1, 66), (1, 67), (1, 68), (1, 69), (1, 70), (1, 71), (1, 82), (1, 83), (1, 84), (1, 85), (1, 86), (1, 87), (1, 88), (1, 98), (1, 120), (1, 121), (1, 122), (1, 123), (1, 124), (1, 141), (1, 142), (1, 143), (2, 2), (2, 11), (2, 12), (2, 13), (2, 14), (2, 23), (2, 24), (2, 25), (2, 26), (2, 27), (2, 36), (2, 37), (2, 38), (2, 39), (2, 40), (2, 41), (2, 50), (2, 51), (2, 52), (2, 53), (2, 54), (2, 55), (2, 65), (2, 66), (2, 67), (2, 68), (2, 69), (2, 70), (2, 71), (2, 82), (2, 83), (2, 84), (2, 85), (2, 86), (2, 87), (2, 88), (2, 98), (2, 120), (2, 121), (2, 122), (2, 
# %%
nonreds = []

for i in bases:
    
    flag = 0
    
    for j in reds:
        
        for k in j:
            
            if i == k:
                
                flag = 1
                
    if flag == 0:
        
        nonreds.append(i)
        
    
print nonreds
# Out:
# [(0, 0), (0, 98), (0, 143), (1, 1), (1, 98), (2, 2), (2, 98), (2, 120), (2, 141), (11, 11), (12, 12), (13, 13), (13, 98), (14, 14), (14, 98), (14, 120), (23, 23), (24, 24), (25, 25), (26, 26), (26, 98), (27, 27), (27, 98), (36, 36), (37, 37), (38, 38), (39, 39), (40, 40), (40, 98), (41, 41), (41, 98), (50, 50), (51, 51), (52, 52), (53, 53), (54, 54), (55, 55), (55, 98), (65, 65), (65, 124), (66, 66), (67, 67), (68, 68), (69, 69), (70, 70), (71, 71), (71, 98), (82, 82), (83, 83), (84, 84), (85, 85), (86, 86), (87, 87), (87, 98), (88, 88), (88, 98), (98, 98), (98, 124), (98, 143), (120, 120), (121, 121), (122, 122), (123, 123), (124, 124), (141, 141), (142, 142), (143, 143)]

# %%
v = deepcopy (uv)

# %%
def signal(amp,width):
    
    temp = np.zeros((60,1024,4))
    
    for i in range(3):
        
        for j in range(10):
            
            temp[i][j][0] = np.random.normal(amp,width)
            
    result = np.fft.fftn(temp)
    
    return result

# %%
def noise(amp,width):
    
    result = np.random.normal(amp,width,(60,1024,4))
    
    return result

# %%
new_data_array = np.zeros((67680, 1, 1024, 4),dtype = complex)

#signal_data_array = np.zeros((67680, 1, 1024, 4),dtype = complex)

#noise_data_array = np.zeros((67680, 1, 1024, 4),dtype = complex)

s_width = 0

s_amp = 0

i_width = 3

i_amp = 0

n_width = 6

n_amp = 0

for i in reds:
        
    sig = signal(s_amp,s_width)
    
    print 'working'
        
    for j in i:
            
        indices = v.antpair2ind(j[0],j[1])
            
        noi = noise(n_amp,n_width)
        
        i_sig = signal(i_amp,i_width)
            
        visibility = sig + noi + i_sig
            
        new_data_array[indices,0,:,:] = visibility
            
        #signal_data_array[index,0,:,:] = sig
            
        #noise_data_array[index,0,:,:] = noi
# Out:
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working

# %%
print new_data_array
# Out:
# [[[[  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    ...,
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]]]
#
#
#  [[[-12.12446322+0.j         -14.55858120+0.j         -18.80733924+0.j
#     -20.14317812+0.j        ]
#    [ -8.87602008+0.29925692j -21.68832815+0.29925692j
#     -22.87850071+0.29925692j -19.46347226+0.29925692j]
#    [-28.44902784+0.59805229j -20.07168791+0.59805229j
#     -18.72850138+0.59805229j -28.85914367+0.59805229j]
#    ...,
#    [-11.03217144-0.89592581j  -4.31578692-0.89592581j
#      -8.73497141-0.89592581j -15.13338921-0.89592581j]
#    [-10.27430152-0.59805229j -16.82604594-0.59805229j
#     -15.01359136-0.59805229j -14.43391285-0.59805229j]
#    [-32.92067464-0.29925692j -15.55101357-0.29925692j
#     -22.41012451-0.29925692j -20.96171406-0.29925692j]]]
#
#
#  [[[  4.52667366+0.j           3.96202184+0.j           2.48467016+0.j
#      -4.49128298+0.j        ]
#    [  8.40000157-0.34880419j  -6.65029711-0.34880419j
#       6.40494242-0.34880419j   9.03807736-0.34880419j]
#    [ -0.17903241-0.69642527j  11.72081674-0.69642527j
#       2.04192893-0.69642527j  -7.42188947-0.69642527j]
#    ...,
#    [  4.33376932+1.04168345j   7.12973043+1.04168345j
#       7.88539565+1.04168345j  -0.20498772+1.04168345j]
#    [-16.83916683+0.69642527j   1.30428896+0.69642527j
#       9.26283839+0.69642527j  13.19342376+0.69642527j]
#    [  0.57205648+0.34880419j   2.86860855+0.34880419j
#       2.79108384+0.34880419j   6.67985773+0.34880419j]]]
#
#
#  ...,
#  [[[  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    ...,
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]]]
#
#
#  [[[  5.29069454+1.46157517j  15.47506318+1.46157517j
#      17.31084447+1.46157517j  12.16170104+1.46157517j]
#    [ 16.67683198+0.58576938j  21.12558891+0.58576938j
#      16.99647063+0.58576938j  12.52720002+0.58576938j]
#    [  4.95312053-0.29443702j  13.63282957-0.29443702j
#      11.30378832-0.29443702j  12.60741955-0.29443702j]
#    ...,
#    [  9.51703054+4.0369816j    3.60875481+4.0369816j
#      14.59987123+4.0369816j   17.82450003+4.0369816j ]
#    [ 11.45847059+3.18971879j  13.46507822+3.18971879j
#       5.08730430+3.18971879j  13.02591070+3.18971879j]
#    [ 23.09475717+2.33040875j  12.17577758+2.33040875j
#      11.57289049+2.33040875j   9.41422016+2.33040875j]]]
#
#
#  [[[  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    ...,
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]
#    [  0.00000000+0.j           0.00000000+0.j           0.00000000+0.j
#       0.00000000+0.j        ]]]]

# %%
for i in nonreds:
    
    print 'working'
        
    sig = signal(s_amp,s_width)
            
    indices = v.antpair2ind(i[0],i[1])
            
    noi = noise(n_amp,n_width)
            
    visibility = sig + noi + i_sig
            
    new_data_array[indices,0,:,:] = visibility
            
    #signal_data_array[index,0,:,:] = sig
            
    #noise_data_array[index,0,:,:] = noi
# Out:
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working

# %%
print new_data_array

#print signal_data_array

#print noise_data_array
# Out:
# [[[[  3.88856261+0.j          19.51076009+0.j           2.77569720+0.j
#       3.71251187+0.j        ]
#    [  5.69659977-0.02049326j  18.90509921-0.02049326j
#      12.71357181-0.02049326j  17.73366977-0.02049326j]
#    [  0.27236761-0.04137563j   4.32986229-0.04137563j
#      14.35477407-0.04137563j  10.33023988-0.04137563j]
#    ...,
#    [  8.74919724+0.06303547j   3.48178172+0.06303547j
#       4.64147658+0.06303547j  14.80679889+0.06303547j]
#    [ 14.60523322+0.04137563j   0.10244627+0.04137563j
#      11.32444611+0.04137563j   5.47505494+0.04137563j]
#    [  5.04307340+0.02049326j   8.06486292+0.02049326j
#       2.11691180+0.02049326j  16.35374433+0.02049326j]]]
#
#
#  [[[-12.12446322+0.j         -14.55858120+0.j         -18.80733924+0.j
#     -20.14317812+0.j        ]
#    [ -8.87602008+0.29925692j -21.68832815+0.29925692j
#     -22.87850071+0.29925692j -19.46347226+0.29925692j]
#    [-28.44902784+0.59805229j -20.07168791+0.59805229j
#    [ 11.04203987+1.79562687j  17.31026994+1.79562687j
#      17.80192314+1.79562687j  13.44396892+1.79562687j]
#    [ 11.47022695+1.76604915j   3.37424939+1.76604915j
#       6.40763199+1.76604915j   2.29242569+1.76604915j]
#    [ 14.49578045+1.73951555j  11.06961916+1.73951555j
#       6.57623157+1.73951555j  11.09830427+1.73951555j]]]]

# %%
v.data_array = new_data_array

# %%
am.data.data_array = new_data_array

# %%
am.xants = []

# %%
z_scores = ant_metrics.red_corr_metrics(v,['xx','yy','xy','yx'],['x','y'],uv.antenna_numbers,reds,am.xants)

# %%
rawRed = ant_metrics.red_corr_metrics(v,['xx','yy','xy','yx'],['x','y'],uv.antenna_numbers,reds,am.xants,rawMetric = True)

# %%
values = []

for key in z_scores.keys():
    
    values.append(z_scores[key]) 

print values
# Out:
# [-1.0374640596667108, -2.2001064059591382, 0.47088336160335165, 0.74298487348534303, 0.28382524241749596, 0.89319716208995092, -1.7372071757787968, -1.1261379071850566, 1.0094601163781323, 1.7577841059540777, -1.8464807447868861, 0.46261335087078531, -0.63977918956557567, 0.97092465420284868, -1.2120976678183391, 0.011135825117887308, 1.6191905948535315, -0.16861563222549056, -0.68669308685784514, 0.56618714959264194, 1.5666574509656697, -0.60987186735547094, -0.45274192214151054, 0.4750511417354133, 0.54820927122839425, 0.75595059865831959, 0.74263489871603372, -0.95696884555855666, -0.23291264584419388, 0.42605521846607669, 0.69084194968403245, -0.84858923076396042, -0.31641631569918521, 0.0, 0.84220245202755273, -1.0210239009601698, 0.0, 0.77479797819847251, -1.6906383752281711, 0.26859768631358527, -0.66302187745549335, -1.0279369313882147, -2.1641707590734485, 0.25921242981025466, -0.68262030534574814, -1.1847378542729143, -0.44171609699654107, 0.58918048792919397, -0.46268405718015776, 1.7842418031632521, 0.2648860992695064, -0.63494527044490912, -0.52306643736374414, 0.44935158641583484, 0.88384982173185145, -0.67076571686348996, 0.060166224186663647, 0.32882630725310946, -0.67449999999999999, 1.3625556930618294, -0.64048571646016705, -0.63908526339811733, -0.55312769368549275, 0.497817089737353, 0.65108454509073055, 1.2970675367202893, -1.1052353063853642, -0.95781689526554903, -0.32042193181191869, 0.57150915568166671, -0.12992805115609057, -0.010635573560539187, 0.43888765933655122, 0.67449999999999999, -1.0041388473685569, -1.0675002544240384, -0.54791855598185968, 3.0302947791208683, 0.61137916383441204, 0.73657407710008438, 0.38202588512889774, -2.9184829401223271, -0.99683309938729037, 3.0050214618416864, -0.74390222488003266, -2.8433649668302299, 0.78464441448928468, -0.17782292561024451, 1.5914050174624117, -1.619682780065455, 0.14061630371600364, 0.56200324626490727, -0.4489872476414834, 1.5875000296962896]

# %%
values_raw = []

for key in rawRed.keys():
    
    values_raw.append(rawRed[key])
    
print values_raw
# Out:
# [0.42883237907789329, 0.42468483912857524, 0.4340512052800749, 0.43020835399655455, 0.43340399111709649, 0.43540764995511699, 0.42628946045583349, 0.430755022366755, 0.42840770718619769, 0.43581067075069746, 0.43840470538087978, 0.42603321131669397, 0.43391504871146136, 0.43488694517490528, 0.43578132962887622, 0.42822815326283814, 0.43246049583478113, 0.43802430576908202, 0.43172691915189132, 0.43004603364980765, 0.43427408306610804, 0.43774217261606518, 0.43031183222351088, 0.4349972240066266, 0.43395816380689495, 0.43431875006290677, 0.43503752736021828, 0.43499145553168644, 0.42899412484796912, 0.43161609716581478, 0.43389610156543934, 0.42936981836828819, 0.4312145741026398, 0.43242196629239016, 0.43523087886973066, 0.42877208060742006, 0.43231141837318565, 0.4308554960132096, 0.42657242014232266, 0.43324250131264763, 0.43012793515746051, 0.4287481168690131, 0.42493401563581157, 0.43320996770324594, 0.42994514288823704, 0.42832281720418491, 0.43078022751430739, 0.43435378853691931, 0.43070754293436841, 0.4385953768356558, 0.43322963524733449, 0.43022507917764374, 0.43061217579565092, 0.43386907734513785, 0.43548005393413769, 0.4301011417599726, 0.4325199821387225, 0.43355969313440257, 0.42997329159597319, 0.43703466218547793, 0.43009120072444196, 0.43009605533794026, 0.43050816496237065, 0.43414439498168211, 0.43467469469954578, 0.43690977192070835, 0.42848016520049442, 0.42910795531626167, 0.43120068879753615, 0.43429253158344716, 0.43197242004846126, 0.4322745505906313, 0.43394050133548462, 0.43475571130612678, 0.42883061195795708, 0.42872845495669754, 0.43041208101592432, 0.4428158117992933, 0.43443073934277943, 0.43486472241035135, 0.43363569554384268, 0.42219461613280351, 0.42897296069532165, 0.44281922923196698, 0.42984809215151343, 0.42258402883712931, 0.43513680690005607, 0.43180670555707368, 0.43792816870060119, 0.42669685398673501, 0.43290849349423938, 0.43436647670554734, 0.43481225384666028, 0.43781442256630421]

# %%
plt.hist(values)
plt.xlabel('z score')
plt.ylabel('Probability')
plt.show()

# %%
plt.hist(values_raw)
plt.xlabel('Redundancy Correlation')
plt.ylabel('Probability')
plt.show()

# %%
data = v.get_data(23,71,'xx')

plt.figure(figsize=(12,12))
#plt.imshow(np.angle(data), aspect='auto', norm=SymLogNorm(vmin=0,vmax=1,linthresh=.1))
plt.imshow(np.abs(data), aspect='auto')
plt.colorbar()
plt.show()

# %%
data = v.get_data(36,87,'xx')

#get the times from a portion of above, convert to LST so we can check it against a good time


plt.figure(figsize=(12,12))
#plt.imshow(np.angle(data), aspect='auto', norm=SymLogNorm(vmin=0,vmax=1,linthresh=.1))
plt.imshow(np.abs(data), aspect='auto')
plt.colorbar()
plt.show()

# %%
data = v.get_data(23,71,'xx')

plt.figure(figsize=(6,6))
#plt.imshow(np.angle(data), aspect='auto', norm=SymLogNorm(vmin=0,vmax=1,linthresh=.1))
plt.imshow(np.abs(data), aspect='auto')
plt.colorbar()
plt.show()



data = v.get_data(36,87,'xx')

plt.figure(figsize=(6,6))
#plt.imshow(np.angle(data), aspect='auto', norm=SymLogNorm(vmin=0,vmax=1,linthresh=.1))
plt.imshow(np.abs(data), aspect='auto')
plt.colorbar()
plt.show()

# %%
data = v.get_data(0,2,'xx')

plt.figure(figsize=(12,12))
#plt.imshow(np.angle(data), aspect='auto', norm=SymLogNorm(vmin=0,vmax=1,linthresh=.1))
plt.imshow(np.abs(data), aspect='auto')
plt.colorbar()
plt.show()
